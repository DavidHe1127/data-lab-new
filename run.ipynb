# %%
import duckdb
import pandas as pd

# %%
sql_query = '''

select * from lab.bronze.payment;

'''

with duckdb.connect('database/lab.db') as con:
    display(con.sql(sql_query))
# Out:
# ┌───────┬─────────┬───────────────┬─────────┬────────┬─────────┬────────────────────────────┐
# │  id   │ orderid │ paymentmethod │ status  │ amount │ created │        _batched_at         │
# │ int32 │  int32  │    varchar    │ varchar │ int32  │  date   │         timestamp          │
# ├───────┼─────────┼───────────────┼─────────┼────────┼─────────┼────────────────────────────┤
# │     1 │       1 │ credit_card   │ NULL    │   1000 │ NULL    │ 2026-01-13 15:07:06.873203 │
# │     2 │       2 │ credit_card   │ NULL    │   2000 │ NULL    │ 2026-01-13 15:07:06.873203 │
# │     3 │       3 │ coupon        │ NULL    │    100 │ NULL    │ 2026-01-13 15:07:06.873203 │
# │     4 │       4 │ coupon        │ NULL    │   2500 │ NULL    │ 2026-01-13 15:07:06.873203 │
# │     5 │       5 │ bank_transfer │ NULL    │   1700 │ NULL    │ 2026-01-13 15:07:06.873203 │
# │     6 │       6 │ credit_card   │ NULL    │    600 │ NULL    │ 2026-01-13 15:07:06.873203 │
# ...
